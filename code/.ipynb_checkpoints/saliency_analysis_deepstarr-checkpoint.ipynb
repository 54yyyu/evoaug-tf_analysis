# %%
import os
import numpy as np
from six.moves import cPickle
import matplotlib.pyplot as plt
from tensorflow import keras
import utils

# %%
# load deepstarr dataset
filepath = '../data/DeepSTARR_data.h5'
x_train, y_train, x_valid, y_valid, x_test, y_test = utils.H5DataLoader(filepath)
_, L, A = x_valid.shape

# %%
output_dir = '../result/'
task = 2

expt_name = 'deepstarr_T_finetune_'+str(task)
model = utils.DeepSTARR(input_shape=(L,A))
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer, loss='mse')
model.load_weights(os.path.join(output_dir, expt_name))

expt_name = 'deepstarr__standard_'+str(task)
model2 = utils.DeepSTARR(input_shape=(L,A))
model2.compile(optimizer, loss='mse')
model2.load_weights(os.path.join(output_dir, expt_name))
# Out:
# 2024-01-03 22:10:24.131350: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-03 22:10:25.153167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46116 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1a:00.0, compute capability: 8.6
# 2024-01-03 22:10:25.153835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 154 MB memory:  -> device: 1, name: NVIDIA TITAN RTX, pci bus id: 0000:68:00.0, compute capability: 7.5

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import logomaker
import pandas as pd

def plot_attribution_map(saliency_df, ax=None, figsize=(20,1)):
  """plot an attribution map using logomaker"""

  logomaker.Logo(saliency_df, figsize=figsize, ax=ax)
  if ax is None:
    ax = plt.gca()
  ax.spines['right'].set_visible(False)
  ax.spines['top'].set_visible(False)
  ax.yaxis.set_ticks_position('none')
  ax.xaxis.set_ticks_position('none')
  plt.xticks([])
  plt.yticks([])


def grad_times_input_to_df(x, grad, alphabet='ACGT'):
  """generate pandas dataframe for saliency plot
     based on grad x inputs """

  x_index = np.argmax(np.squeeze(x), axis=1)
  grad = np.squeeze(grad)
  L, A = grad.shape

  seq = ''
  saliency = np.zeros((L))
  for i in range(L):
    seq += alphabet[x_index[i]]
    saliency[i] = grad[i,x_index[i]]

  # create saliency matrix
  saliency_df = logomaker.saliency_to_matrix(seq=seq, values=saliency)
  return saliency_df


@tf.function
def saliency_map(X, model, class_index=None, func=tf.math.reduce_mean):
  """fast function to generate saliency maps"""
  if not tf.is_tensor(X):
    X = tf.Variable(X)

  with tf.GradientTape() as tape:
    tape.watch(X)
    if class_index is not None:
      outputs = model(X)[:, class_index]
    else:
      outputs = func(model(X))
  return tape.gradient(outputs, X)


def grad_times_input(x, scores):
  new_scores = []
  for i, score in enumerate(scores):
    new_scores.append(np.sum(x[i]*score, axis=1))
  return np.array(new_scores)


def grad_correction(x):
  return x - np.mean(x, axis=2, keepdims=True)

# %%
pred = model.predict(x_test)
index = np.argsort(pred[:,0])[::-1]
X = x_test[index[:10]]

scores = saliency_map(X, model, class_index=0)
scores = grad_correction(scores)


scores2 = saliency_map(X, model2, class_index=0)
scores2 = grad_correction(scores2)
# Out:
# 2024-01-03 22:10:46.716738: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2024-01-03 22:10:48.060077: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
for index in range(10):

    fig = plt.figure(figsize=(20,2))
    ax = plt.subplot(2,1,1)
    saliency_df = grad_times_input_to_df(X[index], scores[index])
    plot_attribution_map(saliency_df, ax, figsize=(20,1))
    
    ax = plt.subplot(2,1,2)
    saliency_df2 = grad_times_input_to_df(X[index], scores2[index])
    plot_attribution_map(saliency_df2, ax, figsize=(20,1))

# %%
import matplotlib.pyplot as plt
import pandas as pd
import logomaker


def filter_max_align_batch(X, model, layer=3, window=24, threshold=0.5, batch_size=1024, max_align=1e4, verbose=1):
  """get alignment of filter activations for visualization"""
  if verbose:
    print("Calculating filter PPM based on activation-based alignments")

  N,L,A = X.shape
  num_filters = model.layers[layer].output.shape[2]

  # Set the left and right window sizes
  window_left = int(window/2)
  window_right = window - window_left

  # get feature maps of 1st convolutional layer after activation
  intermediate = keras.Model(inputs=model.inputs, outputs=model.layers[layer].output)

  # batch the data
  dataset = tf.data.Dataset.from_tensor_slices(X)
  batches = dataset.batch(batch_size)
  
  # loop over batches to capture MAX activation
  if verbose:
    print('  Calculating MAX activation')
  MAX = np.zeros(num_filters)
  for x in batches:

    # get feature map for mini-batch
    fmap = intermediate.predict(x, verbose=0)

    # loop over each filter to find "active" positions
    for f in range(num_filters):
      MAX[f] = np.maximum(MAX[f], np.max(fmap[:,:,f]))


  # loop over each filter to find "active" positions
  W = []
  counts = []
  for f in range(num_filters):
    if verbose:
      print("    processing %d out of %d filters"%(f+1, num_filters))
    status = 0

    # compile sub-model to get feature map
    intermediate = keras.Model(inputs=model.inputs, outputs=model.layers[layer].output[:,:,f])

    # loop over each batch
    #dataset = tf.data.Dataset.from_tensor_slices(X)
    seq_align_sum = np.zeros((window, A)) # running sum
    counter = 0                            # counts the number of sequences in alignment
    status = 1                            # monitors whether depth of alignment has reached max_align
    for x in batches:
      if status:

        # get feature map for a batch sequences
        fmaps = intermediate.predict(x, verbose=0)

        # Find regions above threshold
        for data_index, fmap in enumerate(fmaps):
          if status:
            pos_index = np.where(fmap > MAX[f] * threshold)[0]

            # Make a sequence alignment centered about each activation (above threshold)
            for i in range(len(pos_index)):
              if status:
                # Determine position of window about each filter activation
                start_window = pos_index[i] - window_left
                end_window = pos_index[i] + window_right

                # Check to make sure positions are valid
                if (start_window > 0) & (end_window < L):
                  seq_align_sum += x[data_index,start_window:end_window,:].numpy()
                  counter += 1
                  if counter == max_align:
                    status = 0
                else:
                  break
          else:
            break
      else:
        if verbose:
          print("      alignment has reached max depth for all filters")
        break

    # calculate position probability matrix of filter
    if verbose:
      print("      %d sub-sequences above threshold"%(counter))
    if counter > 0:
      W.append(seq_align_sum/counter)
    else:
      W.append(np.ones((window,A))/A)
    counts.append(counter)
  return np.array(W), np.array(counts)




def plot_filters(W, fig, num_cols=8, alphabet='ACGT', names=None, fontsize=12):
  """plot 1st layer convolutional filters"""

  num_filter, filter_len, A = W.shape
  num_rows = np.ceil(num_filter/num_cols).astype(int)

  fig.subplots_adjust(hspace=0.2, wspace=0.2)
  for n, w in enumerate(W):
    ax = fig.add_subplot(num_rows,num_cols,n+1)

    # Calculate sequence logo heights -- information
    I = np.log2(4) + np.sum(w * np.log2(w+1e-7), axis=1, keepdims=True)
    logo = I*w

    # Create DataFrame for logomaker
    counts_df = pd.DataFrame(data=0.0, columns=list(alphabet), index=list(range(filter_len)))
    for a in range(A):
      for l in range(filter_len):
        counts_df.iloc[l,a] = logo[l,a]

    logomaker.Logo(counts_df, ax=ax)
    ax = plt.gca()
    ax.set_ylim(0,2)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    plt.xticks([])
    plt.yticks([])
    if names is not None:
        plt.ylabel(names[n], fontsize=fontsize)

# %%
W, counts = filter_max_align_batch(x_test, model, layer=3, window=20, threshold=0.8, batch_size=1024, max_align=1e4)

fig = plt.figure(figsize=(20,4))
W_df = plot_filters(W, fig, num_cols=8, alphabet='ACGT')
# Out:
# Calculating filter PPM based on activation-based alignments
#   Calculating MAX activation
#     processing 1 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 2 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 3 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 4 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 5 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 6 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 7 out of 256 filters
#       9010 sub-sequences above threshold
#     processing 8 out of 256 filters
#       9123 sub-sequences above threshold
#     processing 9 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 10 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 11 out of 256 filters
#       9902 sub-sequences above threshold
#     processing 12 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 13 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 14 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 15 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 16 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 17 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 18 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 19 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 20 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 21 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 22 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 23 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 24 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 25 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 26 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 27 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 28 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 29 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 30 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 31 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 32 out of 256 filters
#       7391 sub-sequences above threshold
#     processing 33 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 34 out of 256 filters
#       8594 sub-sequences above threshold
#     processing 35 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 36 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 37 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 38 out of 256 filters
#       7129 sub-sequences above threshold
#     processing 39 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 40 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 41 out of 256 filters
#       8150 sub-sequences above threshold
#     processing 42 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 43 out of 256 filters
#       8542 sub-sequences above threshold
#     processing 44 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 45 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 46 out of 256 filters
#       8115 sub-sequences above threshold
#     processing 47 out of 256 filters
#       7223 sub-sequences above threshold
#     processing 48 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 49 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 50 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 51 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 52 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 53 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 54 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 55 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 56 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 57 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 58 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 59 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 60 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 61 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 62 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 63 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 64 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 65 out of 256 filters
#       8336 sub-sequences above threshold
#     processing 66 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 67 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 68 out of 256 filters
#       4562 sub-sequences above threshold
#     processing 69 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 70 out of 256 filters
#       8529 sub-sequences above threshold
#     processing 71 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 72 out of 256 filters
#       9733 sub-sequences above threshold
#     processing 73 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 74 out of 256 filters
#       9458 sub-sequences above threshold
#     processing 75 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 76 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 77 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 78 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 79 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 80 out of 256 filters
#       5931 sub-sequences above threshold
#     processing 81 out of 256 filters
#       7528 sub-sequences above threshold
#     processing 82 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 83 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 84 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 85 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 86 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 87 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 88 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 89 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 90 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 91 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 92 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 93 out of 256 filters
#       7668 sub-sequences above threshold
#     processing 94 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 95 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 96 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 97 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 98 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 99 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 100 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 101 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 102 out of 256 filters
#       7799 sub-sequences above threshold
#     processing 103 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 104 out of 256 filters
#       7090 sub-sequences above threshold
#     processing 105 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 106 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 107 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 108 out of 256 filters
#       4681 sub-sequences above threshold
#     processing 109 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 110 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 111 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 112 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 113 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 114 out of 256 filters
#       8035 sub-sequences above threshold
#     processing 115 out of 256 filters
#       8560 sub-sequences above threshold
#     processing 116 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 117 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 118 out of 256 filters
#       6800 sub-sequences above threshold
#     processing 119 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 120 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 121 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 122 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 123 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 124 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 125 out of 256 filters
#       7901 sub-sequences above threshold
#     processing 126 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 127 out of 256 filters
#       7207 sub-sequences above threshold
#     processing 128 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 129 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 130 out of 256 filters
#       8956 sub-sequences above threshold
#     processing 131 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 132 out of 256 filters
#       9587 sub-sequences above threshold
#     processing 133 out of 256 filters
#       9996 sub-sequences above threshold
#     processing 134 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 135 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 136 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 137 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 138 out of 256 filters
#       4519 sub-sequences above threshold
#     processing 139 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 140 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 141 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 142 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 143 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 144 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 145 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 146 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 147 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 148 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 149 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 150 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 151 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 152 out of 256 filters
#       7917 sub-sequences above threshold
#     processing 153 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 154 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 155 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 156 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 157 out of 256 filters
#       8705 sub-sequences above threshold
#     processing 158 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 159 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 160 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 161 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 162 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 163 out of 256 filters
#       5402 sub-sequences above threshold
#     processing 164 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 165 out of 256 filters
#       5637 sub-sequences above threshold
#     processing 166 out of 256 filters
#       7552 sub-sequences above threshold
#     processing 167 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 168 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 169 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 170 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 171 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 172 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 173 out of 256 filters
#       8545 sub-sequences above threshold
#     processing 174 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 175 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 176 out of 256 filters
#       9390 sub-sequences above threshold
#     processing 177 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 178 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 179 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 180 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 181 out of 256 filters
#       9551 sub-sequences above threshold
#     processing 182 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 183 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 184 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 185 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 186 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 187 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 188 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 189 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 190 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 191 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 192 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 193 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 194 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 195 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 196 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 197 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 198 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 199 out of 256 filters
#       8648 sub-sequences above threshold
#     processing 200 out of 256 filters
#       9285 sub-sequences above threshold
#     processing 201 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 202 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 203 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 204 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 205 out of 256 filters
#       7787 sub-sequences above threshold
#     processing 206 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 207 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 208 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 209 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 210 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 211 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 212 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 213 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 214 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 215 out of 256 filters
#       9108 sub-sequences above threshold
#     processing 216 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 217 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 218 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 219 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 220 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 221 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 222 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 223 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 224 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 225 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 226 out of 256 filters
#       10000 sub-sequences above threshold
#     processing 227 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 228 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 229 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 230 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 231 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 232 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 233 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 234 out of 256 filters
#       8872 sub-sequences above threshold
#     processing 235 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 236 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 237 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 238 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 239 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 240 out of 256 filters
#       9109 sub-sequences above threshold
#     processing 241 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 242 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 243 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 244 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 245 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 246 out of 256 filters
#       9985 sub-sequences above threshold
#     processing 247 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 248 out of 256 filters
#       9936 sub-sequences above threshold
#     processing 249 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 250 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 251 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 252 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 253 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 254 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 255 out of 256 filters
#       7509 sub-sequences above threshold
#     processing 256 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold

# %%
W2, counts2 = filter_max_align_batch(x_test, model2, layer=3, window=20, threshold=0.8, batch_size=1024, max_align=1e4)

fig = plt.figure(figsize=(20,4))
W2_df = plot_filters(W2, fig, num_cols=8, alphabet='ACGT')
# Out:
# Calculating filter PPM based on activation-based alignments
#   Calculating MAX activation
#     processing 1 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 2 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 3 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 4 out of 256 filters
#       7017 sub-sequences above threshold
#     processing 5 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 6 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 7 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 8 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 9 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 10 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 11 out of 256 filters
#       9634 sub-sequences above threshold
#     processing 12 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 13 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 14 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 15 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 16 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 17 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 18 out of 256 filters
#       7921 sub-sequences above threshold
#     processing 19 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 20 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 21 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 22 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 23 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 24 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 25 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 26 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 27 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 28 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 29 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 30 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 31 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 32 out of 256 filters
#       9131 sub-sequences above threshold
#     processing 33 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 34 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 35 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 36 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 37 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 38 out of 256 filters
#       8283 sub-sequences above threshold
#     processing 39 out of 256 filters
#       8061 sub-sequences above threshold
#     processing 40 out of 256 filters
#       5178 sub-sequences above threshold
#     processing 41 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 42 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 43 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 44 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 45 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 46 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 47 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 48 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 49 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 50 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 51 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 52 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 53 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 54 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 55 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 56 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 57 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 58 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 59 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 60 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 61 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 62 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 63 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 64 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 65 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 66 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 67 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 68 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 69 out of 256 filters
#       7301 sub-sequences above threshold
#     processing 70 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 71 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 72 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 73 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 74 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 75 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 76 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 77 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 78 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 79 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 80 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 81 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 82 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 83 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 84 out of 256 filters
#       6940 sub-sequences above threshold
#     processing 85 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 86 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 87 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 88 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 89 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 90 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 91 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 92 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 93 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 94 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 95 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 96 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 97 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 98 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 99 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 100 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 101 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 102 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 103 out of 256 filters
#       9861 sub-sequences above threshold
#     processing 104 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 105 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 106 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 107 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 108 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 109 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 110 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 111 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 112 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 113 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 114 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 115 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 116 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 117 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 118 out of 256 filters
#       6958 sub-sequences above threshold
#     processing 119 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 120 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 121 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 122 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 123 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 124 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 125 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 126 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 127 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 128 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 129 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 130 out of 256 filters
#       9850 sub-sequences above threshold
#     processing 131 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 132 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 133 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 134 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 135 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 136 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 137 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 138 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 139 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 140 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 141 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 142 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 143 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 144 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 145 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 146 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 147 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 148 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 149 out of 256 filters
#       8169 sub-sequences above threshold
#     processing 150 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 151 out of 256 filters
#       3729 sub-sequences above threshold
#     processing 152 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 153 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 154 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 155 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 156 out of 256 filters
#       6498 sub-sequences above threshold
#     processing 157 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 158 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 159 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 160 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 161 out of 256 filters
#       7751 sub-sequences above threshold
#     processing 162 out of 256 filters
#       8760 sub-sequences above threshold
#     processing 163 out of 256 filters
#       9332 sub-sequences above threshold
#     processing 164 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 165 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 166 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 167 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 168 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 169 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 170 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 171 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 172 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 173 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 174 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 175 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 176 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 177 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 178 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 179 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 180 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 181 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 182 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 183 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 184 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 185 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 186 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 187 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 188 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 189 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 190 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 191 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 192 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 193 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 194 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 195 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 196 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 197 out of 256 filters
#       9028 sub-sequences above threshold
#     processing 198 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 199 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 200 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 201 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 202 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 203 out of 256 filters
#       9740 sub-sequences above threshold
#     processing 204 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 205 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 206 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 207 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 208 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 209 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 210 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 211 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 212 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 213 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 214 out of 256 filters
#       9684 sub-sequences above threshold
#     processing 215 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 216 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 217 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 218 out of 256 filters
#       7523 sub-sequences above threshold
#     processing 219 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 220 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 221 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 222 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 223 out of 256 filters
#       9708 sub-sequences above threshold
#     processing 224 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 225 out of 256 filters
#       9790 sub-sequences above threshold
#     processing 226 out of 256 filters
#       alignment has reached max depth for all filters
#       10000 sub-sequences above threshold
#     processing 227 out of 256 filters
